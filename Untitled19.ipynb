# %% [markdown]
# <a href="https://colab.research.google.com/github/2403a54116-blip/sreenidhi-NLP/blob/main/Untitled19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
import spacy
nlp = spacy.load("en_core_web_sm")

text_to_process = "The quick brown fox jumps over the lazy dog."
doc = nlp(text_to_process)
words = nltk.word_tokenize(text_to_process)
pos_tags = nltk.pos_tag(words)
spacy_tags=[]
for token in doc:
    spacy_tags.append((token.text, token.pos_, token.tag_))

print("NLTK tags                  Spacy tags")
for i in range(len(pos_tags)):
    print(f"{pos_tags[i]}          {spacy_tags[i]}")
nltk_noun=0
nltk_verb=0
spacy_noun=0
spacy_verb=0
for (i,j) in pos_tags:
    if j.startswith('V'):
        nltk_verb= nltk_verb+1
    if j.startswith('N'):
        nltk_noun=nltk_noun+1
for i,j,k in spacy_tags:
    if k.startswith('V'):
        spacy_verb= spacy_verb+1
    if k.startswith('N'):
        spacy_noun=spacy_noun+1
print("NLTK Noun count:",nltk_noun)
print("Spacy Noun count:",spacy_noun)
print("NLTK Verb count:",nltk_verb)
print("Spacy Verb count:",spacy_verb)
# Out:
# NLTK tags                  Spacy tags
# ('The', 'DT')          ('The', 'DET', 'DT')
# ('quick', 'JJ')          ('quick', 'ADJ', 'JJ')
# ('brown', 'NN')          ('brown', 'ADJ', 'JJ')
# ('fox', 'NN')          ('fox', 'NOUN', 'NN')
# ('jumps', 'VBZ')          ('jumps', 'VERB', 'VBZ')
# ('over', 'IN')          ('over', 'ADP', 'IN')
# ('the', 'DT')          ('the', 'DET', 'DT')
# ('lazy', 'JJ')          ('lazy', 'ADJ', 'JJ')
# ('dog', 'NN')          ('dog', 'NOUN', 'NN')
# ('.', '.')          ('.', 'PUNCT', '.')
# NLTK Noun count: 3
# Spacy Noun count: 2
# NLTK Verb count: 1
# Spacy Verb count: 1
